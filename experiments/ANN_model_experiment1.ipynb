# %% [markdown]
# **Shallow ANN model with minimal MRI features and Clinical Scores**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report

# %%
# Load cleaned data
df = pd.read_csv("ADNI_baseline_clean.csv")

# %%
df.head()
# Out:
#          PTID   AGE  APOE4  Hippocampus        ICV  MMSE  CDRSB        DX  \
# 0  011_S_0002  74.3    0.0       8336.0  1984660.0  28.0    0.0        CN
# 1  011_S_0003  81.3    1.0       5319.0  1920690.0  20.0    4.5  Dementia
# 2  022_S_0004  67.5    0.0       6869.0  1679440.0  27.0    1.0       MCI
# 3  011_S_0005  73.7    0.0       7075.0  1640770.0  29.0    0.0        CN
# 4  100_S_0006  80.4    0.0       5348.0  1485830.0  25.0    0.5       MCI
#
#    Hippocampus_ICV
# 0         0.004200
# 1         0.002769
# 2         0.004090
# 3         0.004312
# 4         0.003599

# %%
# Drop unnecessary columns
df = df.drop(columns=['Hippocampus', 'ICV'], errors='ignore')

# %%
df.head()
# Out:
#          PTID   AGE  APOE4  MMSE  CDRSB        DX  Hippocampus_ICV
# 0  011_S_0002  74.3    0.0  28.0    0.0        CN         0.004200
# 1  011_S_0003  81.3    1.0  20.0    4.5  Dementia         0.002769
# 2  022_S_0004  67.5    0.0  27.0    1.0       MCI         0.004090
# 3  011_S_0005  73.7    0.0  29.0    0.0        CN         0.004312
# 4  100_S_0006  80.4    0.0  25.0    0.5       MCI         0.003599

# %%
# Encode target variable (DX)
label_encoder = LabelEncoder()
df['DX_encoded'] = label_encoder.fit_transform(df['DX'])  # CN=0, Dementia=1, MCI=2
y = to_categorical(df['DX_encoded'])

# %%
df.head(10)
# Out:
#          PTID   AGE  APOE4  MMSE  CDRSB        DX  Hippocampus_ICV  DX_encoded
# 0  011_S_0002  74.3    0.0  28.0    0.0        CN         0.004200           0
# 1  011_S_0003  81.3    1.0  20.0    4.5  Dementia         0.002769           1
# 2  022_S_0004  67.5    0.0  27.0    1.0       MCI         0.004090           2
# 3  011_S_0005  73.7    0.0  29.0    0.0        CN         0.004312           0
# 4  100_S_0006  80.4    0.0  25.0    0.5       MCI         0.003599           2
# 5  022_S_0007  75.4    1.0  20.0    6.0  Dementia         0.004971           1
# 6  011_S_0010  73.9    1.0  24.0    5.0  Dementia         0.003728           1
# 7  022_S_0014  78.5    0.0  29.0    0.0        CN         0.005301           0
# 8  100_S_0015  80.8    1.0  29.0    0.0        CN         0.004485           0
# 9  011_S_0016  65.4    1.0  28.0    0.0        CN         0.005406           0

# %%
# Feature matrix
X = df[['AGE', 'MMSE', 'CDRSB', 'APOE4', 'Hippocampus_ICV']]

# %%
# Stratified Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Import necessary module
from sklearn.utils import class_weight

# Compute class weights to handle imbalance
# Get class labels from y_train (assuming it's one-hot encoded)
y_train_labels = np.argmax(y_train, axis=1)

class_weights = class_weight.compute_class_weight(
    class_weight='balanced', classes=np.unique(y_train_labels), y=y_train_labels
)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Build a shallow ANN model
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(3, activation='softmax')  # 3 output classes
])

# %%
from tensorflow.keras.optimizers import Adam  # Import the Adam optimizer

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Setup early stopping
early_stop = EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)

# %%
# Train the model
history = model.fit(
    X_train_scaled, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    class_weight=class_weight_dict,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4715 - loss: 0.9880 - val_accuracy: 0.5801 - val_loss: 0.8653
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6134 - loss: 0.8209 - val_accuracy: 0.6012 - val_loss: 0.7399
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6191 - loss: 0.6563 - val_accuracy: 0.6586 - val_loss: 0.6519
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6906 - loss: 0.5528 - val_accuracy: 0.6918 - val_loss: 0.5845
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7395 - loss: 0.4764 - val_accuracy: 0.7462 - val_loss: 0.5250
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7981 - loss: 0.4188 - val_accuracy: 0.8006 - val_loss: 0.4770
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7933 - loss: 0.4043 - val_accuracy: 0.8157 - val_loss: 0.4461
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8369 - loss: 0.3725 - val_accuracy: 0.8248 - val_loss: 0.4035
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8425 - loss: 0.3564 - val_accuracy: 0.8369 - val_loss: 0.3894
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8085 - loss: 0.3550 - val_accuracy: 0.8550 - val_loss: 0.3692
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8342 - loss: 0.3275 - val_accuracy: 0.8520 - val_loss: 0.3544
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8626 - loss: 0.2866 - val_accuracy: 0.8550 - val_loss: 0.3465
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8724 - loss: 0.3030 - val_accuracy: 0.8520 - val_loss: 0.3386
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8537 - loss: 0.2728 - val_accuracy: 0.8640 - val_loss: 0.3310
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8577 - loss: 0.2867 - val_accuracy: 0.8550 - val_loss: 0.3268
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8509 - loss: 0.2849 - val_accuracy: 0.8489 - val_loss: 0.3225
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8736 - loss: 0.2522 - val_accuracy: 0.8640 - val_loss: 0.3164
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8845 - loss: 0.2648 - val_accuracy: 0.8550 - val_loss: 0.3153
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8896 - loss: 0.2527 - val_accuracy: 0.8610 - val_loss: 0.3016
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8767 - loss: 0.2690 - val_accuracy: 0.8610 - val_loss: 0.3039
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8691 - loss: 0.2739 - val_accuracy: 0.8671 - val_loss: 0.2964
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8885 - loss: 0.2162 - val_accuracy: 0.8701 - val_loss: 0.3009
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8751 - loss: 0.2539 - val_accuracy: 0.8640 - val_loss: 0.2945
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8732 - loss: 0.2655 - val_accuracy: 0.8822 - val_loss: 0.2936
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8853 - loss: 0.2441 - val_accuracy: 0.8701 - val_loss: 0.2907
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8784 - loss: 0.2389 - val_accuracy: 0.8761 - val_loss: 0.2929
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8955 - loss: 0.2210 - val_accuracy: 0.8761 - val_loss: 0.2930
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8865 - loss: 0.2285 - val_accuracy: 0.8731 - val_loss: 0.2940
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8939 - loss: 0.2371 - val_accuracy: 0.8731 - val_loss: 0.2875
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8849 - loss: 0.2412 - val_accuracy: 0.8882 - val_loss: 0.2904
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9089 - loss: 0.2245 - val_accuracy: 0.8671 - val_loss: 0.2940
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8771 - loss: 0.2349 - val_accuracy: 0.8882 - val_loss: 0.2834
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9010 - loss: 0.2362 - val_accuracy: 0.8761 - val_loss: 0.2878
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8884 - loss: 0.2363 - val_accuracy: 0.8852 - val_loss: 0.2808
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8841 - loss: 0.2697 - val_accuracy: 0.8792 - val_loss: 0.2854
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8957 - loss: 0.2204 - val_accuracy: 0.8882 - val_loss: 0.2817
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9067 - loss: 0.2210 - val_accuracy: 0.8822 - val_loss: 0.2787
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8963 - loss: 0.2132 - val_accuracy: 0.8973 - val_loss: 0.2869
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9194 - loss: 0.1872 - val_accuracy: 0.8761 - val_loss: 0.2883
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9119 - loss: 0.1965 - val_accuracy: 0.8973 - val_loss: 0.2807
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8917 - loss: 0.2293 - val_accuracy: 0.8882 - val_loss: 0.2761
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9011 - loss: 0.2093 - val_accuracy: 0.8822 - val_loss: 0.2766
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9036 - loss: 0.2304 - val_accuracy: 0.8852 - val_loss: 0.2789
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9217 - loss: 0.1934 - val_accuracy: 0.8852 - val_loss: 0.2744
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9097 - loss: 0.2122 - val_accuracy: 0.8973 - val_loss: 0.2783
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9157 - loss: 0.1933 - val_accuracy: 0.8943 - val_loss: 0.2799
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9016 - loss: 0.2108 - val_accuracy: 0.8882 - val_loss: 0.2769
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9106 - loss: 0.2102 - val_accuracy: 0.8912 - val_loss: 0.2788
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9135 - loss: 0.2068 - val_accuracy: 0.8973 - val_loss: 0.2801
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9175 - loss: 0.2038 - val_accuracy: 0.8912 - val_loss: 0.2756
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9055 - loss: 0.1938 - val_accuracy: 0.8852 - val_loss: 0.2827
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9188 - loss: 0.1929 - val_accuracy: 0.8912 - val_loss: 0.2774
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9174 - loss: 0.1926 - val_accuracy: 0.8973 - val_loss: 0.2822
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9101 - loss: 0.2069 - val_accuracy: 0.8882 - val_loss: 0.2828

# %%
# Evaluate on test set
test_loss, test_acc = model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"\nTest Accuracy: {test_acc:.2f}")
# Out:
# Test Accuracy: 0.92

# %%
# Classification report
y_pred = model.predict(X_test_scaled).argmax(axis=1)
y_test_labels = np.argmax(y_test, axis=1) # Convert y_test to multiclass format
print("\nClassification Report:")
print(classification_report(y_test_labels, y_pred)) # Use y_test_labels instead of y_test
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       160
#            1       0.78      0.90      0.84        68
#            2       0.94      0.88      0.91       186
#
#     accuracy                           0.92       414
#    macro avg       0.90      0.92      0.91       414
# weighted avg       0.93      0.92      0.92       414

# %%
# Import necessary module
from sklearn.metrics import classification_report, confusion_matrix  # Import confusion_matrix


print("\nConfusion Matrix:")
print(confusion_matrix(y_test_labels, y_pred))  # Use y_test_labels instead of y_test
# Out:
# Confusion Matrix:
# [[157   0   3]
#  [  0  61   7]
#  [  5  17 164]]

# %%
# Save model and scaler (optional)
model.save("adni_ann_model.h5")
import joblib
joblib.dump(scaler, "scaler.pkl")

print("\nModel and scaler saved.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model and scaler saved.
